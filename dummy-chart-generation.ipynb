# %%
import matplotlib.pyplot as plt
# magic to display in between cells
# %matplotlib inline
import matplotlib
# %config InlineBackend.figure_format = 'retina'

# %%
# library & dataset|
import seaborn as sns
sns.set()
data = sns.load_dataset('iris')

# %%
matplotlib.rcParams['figure.dpi'] = 120
matplotlib.rcParams['figure.figsize'] = 12, 10

# %%
with sns.axes_style("white"):
    sns.kdeplot(data.sepal_length, data.sepal_width)

# %%
with sns.axes_style("white"):
    sns.jointplot(x=data.sepal_width, y=data.petal_width, kind='kde', shade_lowest=False)

# %%
tips = sns.load_dataset("tips")

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
plt.figure(figsize=(8, 8))
sns.regplot(tips.total_bill[tips.sex == 'Female'], tips.tip[tips.sex == 'Female'])
